# %%
import numpy as np
import nltk
import pandas as pd
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import warnings
warnings.filterwarnings('ignore')

import pyLDAvis
import pyLDAvis.gensim
from nltk.corpus import stopwords

from pprint import pprint

# %% [markdown]
# # Import data

# %%
filename = "data/airbnb.csv"

df = pd.read_csv(filename)
display(df.head(5))
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# 1  Real Bed              strict          True  ...  40.766115  -73.989040
# 2  Real Bed            moderate          True  ...  40.808110  -73.943756
# 3  Real Bed            flexible          True  ...  37.772004 -122.431619
# 4  Real Bed            moderate          True  ...  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
# 3                 0                  NaN
# 4                 4                 40.0
#
#                                        thumbnail_url  zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0   2.0
# 4                                                NaN    20009      0.0   1.0
#
# [5 rows x 29 columns]

# %%
text_col = 'description'

# %% [markdown]
# # Class

# %%
class NLP():
    def preprocess(self, df, lemmatize = False):
        """
        df: text pd.Series
        
        Standard text data preprocessing on text data column
        Returns the preprocessed column
        """
        # Preprocessing
        data = df.copy(deep = True)
        # To lowercase
        data = data.apply(lambda x: x.lower())
        # Remove stop words
        stop = stopwords.words('english')
        data = data.apply(lambda x: " ".join(x for x in x.split() if x not in stop))
        if lemmatize:
            from nltk.stem.wordnet import WordNetLemmatizer 
            lem = WordNetLemmatizer()
            data = data.apply(lambda x: " ".join([lem.lemmatize(word) for word in x.split()]))
        # Remove top 10 most frequent words
        freq = pd.Series(' '.join(data).split()).value_counts()[:10]
        print("Most frequent words, removed:\n", freq)
        freq = list(freq.index)
        data = data.apply(lambda x: " ".join(x for x in x.split() if x not in freq))
        # Tokenize, to_lowercase
        data = data.apply(lambda x: gensim.utils.simple_preprocess(x))
        # Make bigram
        bigram = gensim.models.Phrases(data, min_count=5, threshold=100)
        bigram_mod = gensim.models.phrases.Phraser(bigram)
        data = data.apply(lambda x: bigram_mod[x])

        return data 
    
    def calc_length(self, df):
        """
        Compute length of text data and number of words
        """
        df['number_of_words'] = data.apply(lambda x: len(x.split(" ")))
        df['length_of_string'] = data.apply(lambda x: len(x))
    
    
    def build_lda_model(self, df, n_topics = 10):
        """
        df: text pd.Series
        n_topics: number of topics
        
        Build a LDA model, assign as a variable to self
        Print main topics
        """
        np.random.seed(10)
        sample = df.sample(len(df)//10)
        id2word = corpora.Dictionary(sample)
        corpus = [id2word.doc2bow(text) for text in sample]
        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                   id2word=id2word,
                                                   num_topics=n_topics, 
                                                   random_state=100,
                                                   update_every=1,
                                                   chunksize=100,
                                                   passes=10,
                                                   alpha='auto',
                                                   per_word_topics=True)
        self.lda_model = lda_model
        self.id2word = id2word
        self.corpus = corpus
        
        pprint(lda_model.print_topics(n_topics,5))
    
    def calc_topic_distribution(self, df):
        """
        df: text pd.Series
        classify: if True, classify each doc according its most probable topic
        
        Calculates the probability of each document to belong to a topic 
        Returns df with new features
        """
        def dist2array(distribution,n_topics):
            """Auxiliary function: Returns array of topic distribution by filling in topics that have 0% probability"""
            mydict = dict(distribution)
            ret = np.array([0 if mydict.get(i)==None else  mydict.get(i) for i in range(n_topics)])
            return ret

        def get_topic_dist_text(text, model):
            """text is a string
            Returns Panda DataFrame of topic distribution"""
            """text is a panda dataframe, index = dates, value = X-th articles of day X """
            # Vectorize
            query = text
            query = model.id2word.doc2bow(query)
            test = model.get_document_topics(query)# Predict topic
            return dist2array(test,model.num_topics)

        def get_topic_dist_df(df, model):
            """df is a panda dataframe, index = dates, value = X-th articles of day X """
            td = np.zeros((len(df),model.num_topics))
            for i in range(len(df)):
                td[i] = get_topic_dist_text(df[i],model)    
            return td
        topic_dist =  get_topic_dist_df(df, self.lda_model)
        return topic_dist

nlp = NLP()

# %% [markdown]
# # Preprocessing

# %%
df['processed_text'] = nlp.preprocess(df[text_col], lemmatize = True)
display(df['processed_text'].sample(10))
# Out:
# Most frequent words, removed:
#  room         57800
# apartment    56772
# bedroom      49210
# private      38386
# living       34564
# one          34006
# located      33255
# minute       32941
# 2            32933
# block        32792
# dtype: int64
# 25605    [level, condo, baths, balcony, le, mile, beach...
# 23355    [sunny, julie, balcony, quiet, green, street, ...
# 59626    [chic, red, painted, rent, beautiful, spanish,...
# 60569    [big, furnished, astoria, ave, th, st, ft, fem...
# 21570    [整洁, 优雅的房间设计风格, 并配有网络, 洗衣机_烘干机, 尽情享受厨房自助用餐, 散步...
# 43945    [beautiful, townhouse, heart, silverlake, next...
# 73404    [great, newly, renovated, apartmentl, away, ti...
# 37927    [warm, homey, two, view, city, front, view, tw...
# 40106    [great, high, ceiling, situated, prime, locati...
# 62116    [place, close, south, street, seaport, wall, s...
# Name: processed_text, dtype: object

# %% [markdown]
# # LDA

# %% [markdown]
# Create LDA model using random 10% of words

# %%
warnings.filterwarnings('ignore')
nlp.build_lda_model(df['processed_text'])
# Out:
# [(0,
#   '0.038*"park" + 0.032*"restaurants" + 0.029*"walking" + 0.026*"distance" + '
#   '0.022*"great"'),
#  (1,
#   '0.035*"boston" + 0.024*"suite" + 0.020*"comfortably" + 0.016*"north" + '
#   '0.016*"child"'),
#  (2,
#   '0.027*"kitchen" + 0.027*"bed" + 0.020*"bathroom" + 0.019*"full" + '
#   '0.018*"space"'),
#  (3,
#   '0.136*"place" + 0.054*"love" + 0.050*"you" + 0.039*"good" + 0.039*"close"'),
#  (4,
#   '0.027*"please" + 0.022*"guest" + 0.019*"clean" + 0.018*"free" + '
#   '0.017*"check"'),
#  (5,
#   '0.041*"hollywood" + 0.035*"beach" + 0.025*"parking" + 0.024*"la" + '
#   '0.021*"mile"'),
#  (6, '0.039*"tv" + 0.025*"wifi" + 0.023*"unit" + 0.022*"fully" + 0.022*"new"'),
#  (7,
#   '0.032*"away" + 0.023*"min" + 0.023*"train" + 0.023*"walk" + 0.019*"subway"'),
#  (8,
#   '0.034*"dc" + 0.020*"include" + 0.016*"capitol" + 0.014*"white" + '
#   '0.011*"design"'),
#  (9,
#   '0.035*"san_francisco" + 0.027*"bay" + 0.025*"harlem" + 0.017*"bridge" + '
#   '0.015*"分钟"')]

# %% [markdown]
# ### Calculate Topic distribution

# %%
topic_dist = nlp.calc_topic_distribution(df['processed_text'])
topic_dist[:5]
# Out:
# array([[0.34016129, 0.0159883 , 0.24625915, 0.02173886, 0.03498174,
#         0.03460427, 0.05211523, 0.16235243, 0.01326873, 0.07853001],
#        [0.15565577, 0.        , 0.30799562, 0.08517253, 0.02905184,
#         0.01122754, 0.09187645, 0.28773046, 0.        , 0.02212713],
#        [0.1006758 , 0.        , 0.41348863, 0.        , 0.07947843,
#         0.01256281, 0.21594732, 0.10533304, 0.01488947, 0.04452284],
#        [0.19895428, 0.02405594, 0.23016661, 0.01152891, 0.02576772,
#         0.03257952, 0.04824295, 0.41686451, 0.        , 0.        ],
#        [0.29223424, 0.        , 0.22674462, 0.05201141, 0.05869599,
#         0.06174876, 0.03700904, 0.24033335, 0.02081039, 0.        ]])

# %% [markdown]
# ### Use topic distribution as features

# %%
df = pd.concat([df, pd.DataFrame(topic_dist, 
                columns = ['DistTopic'+str(i) for i in range(nlp.lda_model.num_topics)])], axis = 1)
display(df.head(5))
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ... DistTopic0 DistTopic1  \
# 0  Real Bed              strict          True  ...   0.340161   0.015988
# 1  Real Bed              strict          True  ...   0.155656   0.000000
# 2  Real Bed            moderate          True  ...   0.100676   0.000000
# 3  Real Bed            flexible          True  ...   0.198954   0.024056
# 4  Real Bed            moderate          True  ...   0.292234   0.000000
#
#   DistTopic2 DistTopic3 DistTopic4 DistTopic5 DistTopic6 DistTopic7  \
# 0   0.246259   0.021739   0.034982   0.034604   0.052115   0.162352
# 1   0.307996   0.085173   0.029052   0.011228   0.091876   0.287730
# 2   0.413489   0.000000   0.079478   0.012563   0.215947   0.105333
# 3   0.230167   0.011529   0.025768   0.032580   0.048243   0.416865
# 4   0.226745   0.052011   0.058696   0.061749   0.037009   0.240333
#
#   DistTopic8  DistTopic9
# 0   0.013269    0.078530
# 1   0.000000    0.022127
# 2   0.014889    0.044523
# 3   0.000000    0.000000
# 4   0.020810    0.000000
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Classification using topic distribution (assigned to most likely topic)

# %%
df['Topic'] = np.argmax(topic_dist, axis = 1)
display(df.head(5))
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ... DistTopic1 DistTopic2  \
# 0  Real Bed              strict          True  ...   0.015988   0.246259
# 1  Real Bed              strict          True  ...   0.000000   0.307996
# 2  Real Bed            moderate          True  ...   0.000000   0.413489
# 3  Real Bed            flexible          True  ...   0.024056   0.230167
# 4  Real Bed            moderate          True  ...   0.000000   0.226745
#
#   DistTopic3 DistTopic4 DistTopic5 DistTopic6 DistTopic7 DistTopic8  \
# 0   0.021739   0.034982   0.034604   0.052115   0.162352   0.013269
# 1   0.085173   0.029052   0.011228   0.091876   0.287730   0.000000
# 2   0.000000   0.079478   0.012563   0.215947   0.105333   0.014889
# 3   0.011529   0.025768   0.032580   0.048243   0.416865   0.000000
# 4   0.052011   0.058696   0.061749   0.037009   0.240333   0.020810
#
#   DistTopic9  Topic
# 0   0.078530      0
# 1   0.022127      2
# 2   0.044523      2
# 3   0.000000      7
# 4   0.000000      0
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Save

# %%
df.to_csv(filename.split(".")[0] + "_LDA.csv")

# %% [markdown]
# ### Example

# %%
for i in range(nlp.lda_model.num_topics):
    print("-------------\nTopic %i:" % i)
    print(nlp.lda_model.print_topic(i))
    print("5 examples:")
    print(df[df.Topic == i].sort_values('DistTopic'+str(i), axis =0)[text_col].sample(5).values)
    #for k in range(5):
    #    print(df.sort_values('Topic'+str(i),axis = 0, ascending = 0)[col].iloc[5])
# Out:
# -------------
# Topic 0:
# 0.038*"park" + 0.032*"restaurants" + 0.029*"walking" + 0.026*"distance" + 0.022*"great" + 0.022*"restaurant" + 0.020*"neighborhood" + 0.019*"walk" + 0.019*"heart" + 0.018*"bars"
# 5 examples:
# ["Spacious 1 bedroom on Bedford Ave.   A 10 minute walk to the JMZ and the L train and one stop from Manhattan.  Located near the best bars, restaurants and cafe's. There is a huge fully stocked kitchen. The living room has a TV with apple TV access. Lots of windows with tons of natural light! Please feel free to email me with any questions. Williamsburg is a great walking neighborhood with access to tons of great shopping, restaurants and bars. 10 minutes walk to the L and JMZ trains.  B62 bus stop is directly in front of the building and will take you straight to the L. This is a walk up building so there is no elevator access."
#  "Our home is in Columbia Heights and walkable to a big playground, a shopping center with Target, the 14th Street Corridor for great restaurants, and the Metro to downtown DC. You’ll love it because it's uncluttered, modern, and family-friendly."
#  'Perfect location for accessing the Presidential Inauguration: My place is close to White House & the National Mall (2 mile walk straight down 16th St) Metro: Columbia Heights: (0.2 miles) Buses: Downtown & Dupont routes (0.1 miles) Multiple grocery stores (0.25 miles): Harris Teeter, Safeway, Giant Restaurants: Plenty You’ll love my place because of an unbeatable location Clean and well furnished apartment with all appliances and conveniences for a great stay in the heart of DC (Columbia Heights, Adams Morgan & Mt Pleasant) Full access to the house (living room, bedroom, kitchen, etc) Columbia Heights - Mt Pleasant - Adams Morgan area is a vibrant part of DC with plenty of things to explore: quirky restaurants and coffee shops, retail options, grocery stores and a rich cultural scene Super close to public transportation (Columbia Heights metro station, 16th St busses to the White House and downtown).  Extremely walkable. 98/100 Walkability Score 88/100 Transit Score (URL HIDDEN)'
#  'Relaxing, peaceful, private 1 bedroom, just steps from the L-train and also near the A, C, J, M,Z.  Cool local cafes, restaurants and bars in walking distance.'
#  "Whether you're looking to be 2 blocks to Prospect Park, 1 block to Brooklyn Botanic Gardens, a short walk to Brooklyn Museum of Art, surrounded by bars and restaurants, in the heart of Lefferts Manor,or just a block from the train, this is your spot! Whether you're looking to be 2 blocks to Prospect Park, 1 block to Brooklyn Botanic Gardens, a short walk to Brooklyn Museum of Art, surrounded by bars and restaurants, in the heart of the historic Lefferts Manor, or just to be a block from the train, this is your spot! Nicely decorated, clean, and spacious, you will really be able to relax here. You can even enjoy a nap in the hammock hanging in the living room! The bedroom has a queen-size bed, and there is a queen-size sofa bed in the living room. Bathroom has a full bath/shower. Brooklyn Botanic Garden membership card available for your use! A stay in this neighborhood is really special. Steps to cultural centers, beautiful nature escapes, sweet coffee shops, food shops, and great bars"]
# -------------
# Topic 1:
# 0.035*"boston" + 0.024*"suite" + 0.020*"comfortably" + 0.016*"north" + 0.016*"child" + 0.015*"chicago" + 0.015*"red" + 0.014*"per" + 0.013*"miles" + 0.012*"condo"
# 5 examples:
# ['Blending historic architecture and modern amenities, our Back Bay apartments offer the very finest in contemporary, sophistication and elegance in the core of Boston. Start your day with a Nespresso coffee, then stroll across the Commonwealth Avenue Mall to the Newbury Street shops, Prudential Center and Copley Square. Each apartment is an impeccable haven from the hubbub of the day-to-day, affording you the finest Boston has to offer. We offer turn down service for an additional cost so you will never need to do dishes or change sheets when you\'re on the go. We provide secure mail and package delivery. Finish the day with casual, or fine dining, all within walking distance of your Boston home. Close proximity to the Financial District, the Charles River, the South End, North End, MGH Hospital and Boston\'s underground, known as "The T." Gloucester St is a quiet street located in the Heart of the Back Bay. we have used West Elm furniture to furnish this unit with upscale beddings and ma'
#  'Blending historic architecture and modern amenities, our Back Bay apartments offer the very finest in contemporary, sophistication and elegance in the core of Boston.  Start your day with a Nespresso coffee, then stroll across the Commonwealth Avenue Mall to the Newbury Street shops, Prudential Center and Copley Square.  Each apartment is an impeccable haven from the hubbub of the day-to-day, affording you the finest Boston has to offer.   We offer turn down service for an additional cost so you will never need to do dishes or change sheets when you\'re on the go. We provide secure mail and package delivery.  Finish the day with casual, or fine dining, all within walking distance of your Boston home. Close proximity to the Financial District, the Charles River, the South End, North End, MGH Hospital and Boston\'s underground, known as "The T." Gloucester St is a quiet street located in the Heart of the Back Bay. we have used West Elm furniture to furnish this unit with upscale beddings a'
#  "Central Boston Location; steps to the MGH, Financial District, Boston Common, Waterfront & North End. Short walk to the Charles River Esplanade. Renovated, fully applianced kitchen with breakfast bar, comfortable bow-front living room. Private parking. Elevator, C/A, Walk to 4 T stations, 2 blocks to 93, Mass Pike & Storrow Drive. 1 Bedroom, 1 Bath, comfortably and tastefully furnished.  Fully applianced kitchen Entire 1 Bedroom apartment Email and Text Centralized location to all of Boston's most important destinations. Central to The following MBTA T and Commuter Rail Stations: Charles/MGH, North Station, Government Center, Park Street. Which includes: red line, green line, blue line, orange line and commuter rail. Walk across Cambridge St to Mass General Hospital"
#  "Enjoy this neat, private entire 2-bedroom Apt unit. You can walk to many Boston Attractions including BostonCommons, Back Bay, Newbury St,  Theatre District, Beacon Hills, Charles River,  Copley Square, The Trinity Church in 10 minutes and walk to all Subway lines and south station in 5 minutes.  It is also surrounded by many great restaurants with any style of cuisine.  Brand new furniture, unique roof deck and city view。NO PARTIES, NO SMOKING ANY KINDS. It's close to some Major Nightlife including many fine dinning restaurants and several area nightclubs, as well as cinemaplex movie theater. You are just minutes away from:  *Universities: Northeastern University, Berklee College, Wentworth University, MassArt, New England Conservatory, Boston Conservatory, Simmons College, Emmanuel College, and Harvard Medical School, MIT *  All the World renowned Hospitals: Brigham & Women’s Hospital, Beth Israel Deaconess Hospital & Children’s Hospital as well as Boston Medical center, Mass General"
#  'This apartment boasts large windows - which offer breathtaking views of the city - gourmet kitchens chicly-styled with flat panel cabinetry, and baths that are inspired by the most elegant spas. Combine this with the unparalleled on-site amenities: the clubroom with a flat screen TV, a private kitchen, rooftop terrace with lounge seating, stainless steel gas grills, and 24-hour customer service and this becomes the only place to stay on y our next trip to Washington, DC! 1 bedroom, 1 bathroom, Sleeps 3 Major Attractions •Restaurants –Carmine’s (.3 mi), China Chilcano (.3 mi), Hill Country BBQ & Market (.3 mi), Oyamel Cocina Mexicana (.2 mi), and The Capital Grille (233 ft) •The Source by Wolfgang Puck – 220 ft •Safeway for groceries – .8 mi •Arlington National Cemetery – 2.8 mi •The Pentagon – 3.7 mi •Marine Corps War Memorial – 5.3 mi •Air Force Memorial – 4.4 mi •Arlington House – home of General Robert E. Lee – 3.2 mi •Long Branch Nature Center & Park – 8.5 mi •National Mall – .1 mi']
# -------------
# Topic 2:
# 0.027*"kitchen" + 0.027*"bed" + 0.020*"bathroom" + 0.019*"full" + 0.018*"space" + 0.016*"access" + 0.016*"two" + 0.016*"area" + 0.015*"home" + 0.015*"large"
# 5 examples:
# ['Large newly remodeled Edwardian home on a quiet street in sunny Mission district. Steps from Valencia St\'s trendy restaurants, galleries, & fun shops.  Just a couple blocks to Dolores Park, public transit (BART & Muni) & gourmet groceries. - Large single family classic Edwardian home  - Wood grain moldings, doors, etc.  - wood floors with Turkish & Persian rugs - 4 large, comfortable bedrooms - 2 brand new full bathrooms (as of 2016) - Huge kitchen, fully stocked with cookware, spices & other essentials - Formal dining room - outdoor deck - small yard - Free WIFI  - 60" Flat screen HD TV in Living Room  - deck & small yard - washer & dryer - board games & toys - XBox We will provide a key and instructions and will let you in or will leave key in lockbox. Located in the thriving "Valencia Street Corridor," this area has become one of San Francisco\'s most exciting neighborhoods with many of the city\'s best restaurants, most interesting shops and galleries - and fun live music venues. Thi'
#  'The room is small and comfy and fit perfect to max 2, located 5 minutes walking from Times Square and most of the subway lines.'
#  "Light and airy boho chic 2 bedroom apartment in beautiful Humbolt Park, with all amenities and free Wifi. Day room to relax, and huge back porch and yard with strung overhead lights. Breathable, plant filled, light apartment, free parking, laundry in building, Division bus stop right in front, just a block away from the beautiful Humbolt Park! Wifi, Netflix/ Amazon Prime/ Hulu, free parking, laundry, kitchen amenities Both my partner and I work full time, so we will not be in the apartment that much. We will greet you when you first arrive, show you around, and answer any questions you may have. At the end of your stay we wee see you off, otherwise we will see in in passing, and will always be available to answer your questions. (Breakfast available upon request) ;) We're just minuets away from Humbolt Park, which is a must see, and very close to all of the  trendy Division street bars, restaurants, and cafes! Uber is perfect, there is also free parking all around, you can also use the"
#  'Amazing basement room with PRIVATE ENTRANCE and PRIVATE BATHROOM in the heart of Bushwick. You’ll love my place because of the privacy and the close location to the M, L or J train.  You also have access to the yard for a smoke break or to feel the weather.  Our place gives you exclusive access to your own private bathroom and your private entrance. The room is fully equipped with a 48" smart TV and a small private refrigerator, everything is brand new, beds, TV, refrigerator etc. 30 minutes away from the city and three train options.  IF THIS LISTING IS UNAVAILABLE FOR THE DAYS YOU WANT TO TRAVEL PLEASE CONTACT ME BECAUSE I ALSO HAVE A SECOND PLACE IN MANHATTAN The big room, its private cute bathroom , laundry and the basement . The privacy of the room allows for regulating the amount of interaction wished by my guests. Although I and my family are always present in the first floor and happy to interact with our guests. Bushwick has approximately 80,000 inhabitants. 70% of Bushwick\'s '
#  "Beautiful NYC one bedroom apartment in desirable Upper West Side neighborhood with high ceilings and a full wall of exposed brick. Prime location just steps from CENTRAL PARK. 4th floor walk up with skylight that provides extra natural day light. The apartment is located: - Half block from Central Park (near Great Lawn, Delacorte Theater) - One block from the B and C trains and 1/2 mile from 1 train - One block from Museum of Natural History - Walking distance to grocery store, pharmacy, shops, restaurants, bars, museums (Met, Guggenheim, Whitney), Riverside Park, flea market, farmer's market and more! Full kitchen includes a dishwasher, microwave, toaster, blender, pots, pans, french press, wine glasses, towels, plates, utensils and other cooking equipment.  The bedroom has a comfortable queen size bed. The living room has a couch that is large enough for an adult to sleep on comfortably. There is also an air mattress available upon request. The living room has  a desk, chair, coffee "]
# -------------
# Topic 3:
# 0.136*"place" + 0.054*"love" + 0.050*"you" + 0.039*"good" + 0.039*"close" + 0.032*"ll" + 0.026*"business_travelers" + 0.021*"couples_solo" + 0.021*"adventurers" + 0.013*"comfy"
# 5 examples:
# ['My place is close to University of Chicago, Public Transportation, Hyde Park Chicago, downtown Chicago. You’ll love my place because of the comfy beds, the kitchen, the large rooms, the neighborhood, in unit laundry. My place is good for couples, solo adventurers, business travelers, and families (with kids).'
#  'My place is close to great views, parks, restaurants and dining, art and culture, the beach is 30 min away to Malibu beach.. You’ll love my place because of the location, is nice quiet, good neighborhood, close to mall, just 7 min away to Topanga mall, close to church, and universal studio and other entertainment places.. My place is good for couples, solo adventurers, business travelers, and families (with kids).'
#  'My place is close to hollwyood, Laugh Factory, The Griddle Cafe, Bossa Nova, Amoeba Music, In-N-Out Burger. You’ll love my place because of the views, the coziness, and the location. My place is good for couples, solo adventurers, and business travelers.'
#  'Walk to the United States Capitol, Union Station, H Street & Eastern Market. You’ll love my place because of the location, neighborhood and huge windows. My place is good for couples, solo adventurers, and furry friends (pets).'
#  'My place is close to Universal Studios, buses and subway, Hollywood Freeway, movie theaters, restaurants, coffee houses, spa salon, parks, etc.  You’ll love my place because of the light, the high ceilings, the full kitchen, the private fenced back yard with bbq. My place is good for couples, solo adventurers, and your canine companion..']
# -------------
# Topic 4:
# 0.027*"please" + 0.022*"guest" + 0.019*"clean" + 0.018*"free" + 0.017*"check" + 0.014*"stay" + 0.013*"use" + 0.013*"provided" + 0.012*"towel" + 0.011*"make"
# 5 examples:
# ["I can park this anywhere legal close to wherever you want to be. It's for stationary lodging but I can move it at your leisure. There will be some extra charges if you want me to jockey it around & if you want it some longer distances as well. Please please note to contact me before you instantly book so we make sure it's actually available and ready. It's listed several places and schedules might conflict. I cannot reimburse cancellation fees if you book without inquiring with me if it's unavailable. I can park this anywhere legal 4 you I or someone can be contacted anytime day or night for anything you need. Caryn Moss search me I'm all over the net. Moss Entertainment. Please please contact me BEFORE you book as I have this RV available with other rental sources & dates may conflict.  I'd like to make sure we're all on the same page as far as what the accommodations will be like, what you need & what all we've got.  Also if it develops any mechanical or technical issues that might m"
#  '***If you want to book OR communicate with us YOU MUST WRITE US THE FOLLOWING: "We have read read ALL 3 Major points listed Below and ALL details, we are ready to book!! " ....Then if you are ready to book press "book it" on your profile and you will be set! This Micro Efficiency Apartment is in one of LA\'s most popular & safe areas ...AND one of the cheapest Private Apartments on Airbnb!!!  Its your own Private Apartment & Private Entrance, Central to everything, ultra stylish and CHEAP!!! ***If you want to book OR communicate with us YOU MUST WRITE US THE FOLLOWING: "We have read read ALL 3 Major points listed Below and ALL details, we are ready to book!! " ....Then if you are ready to book press "book it" on your profile and you will be set!" ****VERY IMPORTANT, READ CAREFULLY!!!!!**** Though this is a Private Apartment with its Own Private Entrance, this is an EFFICIENCY Studio!!!! Which means 3 very important things: 1. It has a 2 SEPARATE BATHROOMS located in the main hall of bld'
#  "Private room in the heart of Little Italy with FREE PARKING :) You will have your own personal door code and may arrive at ANY time you would like and as late as you wish. You can store your luggage in the closet before check-in and after check-out times :) Price adapts to demand, my rates change constantly - every night is different! Put your dates in the calendar, with the number of guests, and what you see is what you'll pay :) The neighborhood is extremely safe even at night :) Restaurants and bars are right round the corner, both upscale and casual. This room is 7 minutes away by car or uber to Chicago's famous Willis (Sears) tower. Uber costs about $7. If you are arriving by car, I am providing free parking passes for anywhere in the zone 5 area. (Yes, that means you can drive around all of Little Italy and more and still park anywhere you want!) You will be given a door code to access the apartment and a key to lock your private room. You may arrive ANY time you would like and a"
#  'Are you passing through or just need a night away from the city? Looking for something simple and low-key. Come stay in a charm-less, overly-Simple apartment. You and a guest can enjoy a hot shower before you check-out. Simple. This is a hostel-type of environment.'
#  "Beautiful Artist loft, clean, beautiful and lovingly decorated in the perfect location for all the best parts of Brooklyn and Manhattan. I block from the Subway, Grocery store, Police station (thus very safe). Car parking freely available directly outside the apartment. It's a real bonus if you know anything about NYC As much or as little as you like, I live an industrious life but always have time to assist guests if they need and also know how to leave people in there own groove if thats what they desire. Neighborhood is great one of the last authentic and peacfeul areas. Great bars and restuarants for both meat lovers and Vegans. There is both the best Steak House in New York (Peter Lugers) and the wonderful Vertu (formerly Moto) for Vegans within just a block or 2 and much more. The JMZ is just one block from the house. gets you to the east village in 2 stops Nolita in 3 and theWest Village in 4. The famous L train is also just a few blocks from the apartment . There is also a huge"
#  "My cozy clean two bedroom apartment is located on Hollywood Blvd. Super central. Less than a ten minute walk to the Hollywood Stars, Hollywood walk of fame, Chinese theater, Runyon Canyon, laugh factory, Sunset strip, Metro red train line, buses and much much more. ~ Private Room ~ Easy Street Parking ~ Clean Cozy Environment ~ Centrally Located near Public Transportation ~ Fast WiFi ~ Runyon Canyon, Laugh Factory, Trader Joe's, Hollywood Walk of Fame and more walking distance from apartment =) ~ Apt is shared with a roommate with private room. Private Bedroom Shared living and dinning area Restroom with shower and tub Wifi Computer in Bedroom Love living in Hollywood.  Feels like the center of Los Angeles. Get to enjoy Hollywood without having to worry about parking and the beach is just a drive away. Los Angeles is definitely known for the worst public transportation.  However, the apartment is centrally located near buses and metro train line. Plus parking is available on side stree"]
# -------------
# Topic 8:
# 0.034*"dc" + 0.020*"include" + 0.016*"capitol" + 0.014*"white" + 0.011*"design" + 0.011*"fitness" + 0.011*"washington" + 0.009*"deep" + 0.009*"metro" + 0.008*"adventure"
# 5 examples:
# ['Enjoy a beautiful contemporary residence with picturesque park views near Fenway Park. Upscale amenities throughout include, fully-equipped kitchens, open floor-plans, oversize windows, spacious walk-in closets, as well as a  pool, fitness center, and clubhouse for your entertainment. 1 BED 1 BATH SLEEPS 3 B1232 For your convenience, we have a guest service representative available in the area. Experience Luxury living in the heart of Boston in these premium residences that will provide you with an uplifting lifestyle and comfortable stay. With a contemporary design throughout this high-rise has cutting-edge finishes and amenities throughout including: fully equipped kitchens with stainless steel and energy efficient appliances, bathrooms with elegant flooring and custom vanities, remarkable views of Olmstead Park, private courtyard with stunning landscaping, and an elevated amenity deck with swimming pool, fireplace & BBQ grills. This spectacular location is home to many major attract'
#  '3房2浴独立屋中两间雅房共用一个卫生间,家具家电齐全,无线上网,拎包入住。步行2分钟到公园、工商银行,步行3分钟到美国,大通,富国,华美和国泰银行,步行5分钟到加州,光华和168等华人超市和多家饭店、星巴克、快餐店,卡拉ok,小吃一条街。步行15分钟到2所小学,附近有多家医院,步行20分钟到嘉惠尔医院'
#  "This posh studio features a modern bathroom, contemporary furnishings, and a fully-equipped kitchen. Located in Downtown Crossing, just steps from the T and minutes to Boston Common. Every booking is instantly confirmed. Every call or message is answered within minutes. Every home is equipped with crisp linens, high-speed Wi-Fi, and kitchen and bath essentials—everything you need for an exceptional stay. Our concierge is available by phone, email, or Messenger 24/7. Don’t hesitate to contact us if you need anything, from extra towels to restaurant recommendations. Otherwise, we’ll leave you to enjoy your stay. Downtown Boston is a pleasure of sights and sounds. Picnic in the park or grab a bite at Archie's New York Deli. Shop around everything from small boutiques to major chains, including America's first Primark, the Ireland-based clothing retailer. For dinner, head over to The Merchant Kitchen & Drinks for late night bite and killer cocktail.  Downtown Crossing is a shopping distric"
#  'The Apartments at City Center are the ultimate in sophisticated urban living. This exclusive residential community in downtown DC is the centerpiece of the vibrant 10-acre City Center DC neighborhood. The 458 luxury residences feature modern layouts, elegance and amenities desired  by the District’s most discerning residents. Centrally located and easily accessible. The Apartments immerse residents in  the District’s best retail, dining, entertainment and culture. The Apartments at City Center redefines urban excellence. Each apartment is stylishly furnished. Kitchens feature: Grohe single-handle chrome kitchen faucet with pull-out spray  -Environmentally responsibly crafted white Ceasarstone countertops  -Bosch natural gas cooktop and electric oven Bedrooms have custom-designed European built-in wardrobe system: ideal function converges with sleek style. Molteni closet systems are designed to be personalized, so residents can easily move the internal fittings, making it easy to modify'
#  'Capitol Hill, "par excellence" Note: No hidden fees!  Our pricing includes , cleaning, linens, cable/wifi and utilities. A. DESCRIPTION Drop your bags and find yourself at the doorstep of global democracy in this handsomely decorated 1 BR sidewalk level apartment in an historic Capitol Hill townhome.  Capitol Hill is one of the most sought-after neighborhoods in Washington, DC because it is an unparalleled location for experiencing the Nation’s Capital; just 2 blocks from Union Station and 3 blocks from the Supreme Court! You’ll have an easy walk to the great sights in DC: The National Mall, The Smithsonian museums, The U.S. Capitol Building and Library of Congress, Supreme Court, Folger Shakespeare Theater and the Botanical Conservatory.  Want to step out of the tourist mold? Rub shoulders with members of Congress and the Senate in one of “The Hill’s” many fine restaurants and eateries within a 2 block radius;  La Loma Restaurant, Café Berlin, Bistro Cacao, Sonoma and Toscanas to name']
# -------------
# Topic 9:
# 0.035*"san_francisco" + 0.027*"bay" + 0.025*"harlem" + 0.017*"bridge" + 0.015*"分钟" + 0.014*"van" + 0.013*"pier" + 0.010*"muni" + 0.009*"toiletries" + 0.009*"astoria"
# 5 examples:
# ['Greetings Masters of the Universe! ************************************************************************** SAN FRANCISCO SHORT-TERM RESIDENTIAL REGISTRATION NUMBER STR-(PHONE NUMBER HIDDEN). Possession of a San Francisco Short-Term Rental Registration Certificate certifies that the registration certificate holder has agreed to comply with the terms of the San Francisco Short-Term Residential Rental Ordinance (San Francisco Administrative Code Section 41A).  This ordinance does not require an inspection of the unit by the City for potential Building, Housing, Fire or other Code violations. ************************************************************************** Castle Dreiskull is a COMFORT WONDERLAND that will make you, your friends and family SUPREMELY happy.  Minutes away from ENDLESS FUN, Castle Dreiskull: Pleasure Den is your 2 bedroom home away from home!  Perfectly located in the safe and clean Castro, Castle Dreiskull is mere steps from the bars, restaurants, clubs and shop'
#  'Charming two bedroom apartment with large living room and great  balcony! SAN FRANCISCO SHORT-TERM RESIDENTIAL RENTAL REGISTRATION NUMBER: STR-(PHONE NUMBER HIDDEN) Possession of a San Francisco Short-Term Rental Registration Certificate certifies that the registration certificate holder has agreed to comply with the terms of the San Francisco Short-Term Residential Rental Ordinance (San Francisco Administrative Code 41A). This ordinance does not require an inspection of the unit by the City for potential Building, Housing, Fire, or other Code violations.'
#  "Mon logement est proche de LACMA, The Grove, RALPHS, Beverly Center. Vous apprécierez mon logement pour l'emplacement, les gens, les espaces extérieurs. Mon logement est parfait pour les couples, les voyageurs en solo et les voyageurs d'affaires."
#  '独立House分租主卧豪华套房,有独立卫浴,安静温馨,美式实木家具,专门车位,好学区好社区好环境,步行可达华人超市,华人餐馆,银行,梅西百货,costco,ross折扣店,marshall折扣店 我家是独立house位于罗兰岗好地段,优雅安静的环境,能保证安静的睡眠,安全的高端社区,位于半山腰,鸟语花香景色秀丽,每天都能呼吸到新鲜的空气,夏季凉风送爽,配套服务好,房子新,阳光充足,配备齐全,(非改建非隔间非后屋的房子)社区学区好,治安好,有监控系统!现房间,欢迎咨询欢迎来看房参观!价格合理,谢绝烟酒宠物, 地理位置极好,离PIH产检医院和购物近 ,步行十分钟可到夜市、华人超巿(海鸥超市,顺发超市,香港超市,邮局,韩国餐馆,各式中餐厅),步行十五分钟可到(Target超市,ross打折卖场,in-n out汉堡等各式中餐厅,半岛早茶餐厅,夜宵)costco,babyrus,ross,Marshall,梅西百货,Burlington,target这些购物mall林集一片,家旁边有小学,幼儿园,语言学校,初高中,十分的好学区,家附近有公园,房子新丶通风好。环境优雅,人口简单,地理位置优越,四通八达,近公交车站,警察局,uber车频用地,生活非常便利。 美国手机(PHONE NUMBER HIDDEN)MiuMiu欢迎您来看房。 有关实际档期,请电或(SENSITIVE CONTENTS HIDDEN)联系(URL HIDDEN)门口有专用停车位供您使用     会客厅       客厅   中式厨房   餐(URL HIDDEN)主卧套房(带独立卫浴 专用停车位配备 经常交流,有问必答 环境好,治安好,便利,安静 罗兰岗(Rowland Heights)位於南加州洛杉矶县东边,为华人华人聚集城市之一,与邻近城市成为南加州最东边也是最新兴的中国城。以可利马大道(Colima Rd)富勒顿大道(Fullerton Ave),洛加勒斯大道(Nogales Ave)和盖尔大道(Gale Ave)为主的商圈, 以华人和韩国商店为主, 商场,超级市场和餐厅林立。每到例假日时,车水马龙,附近的亚裔居民或是游客蜂拥到商圈内的超市或餐厅享受家乡美味。 罗兰岗是美国加州洛杉矶县的一个未建制社区(unincorporated community)。占地约30平方公里(11.4 平方英里)。20'
#  '您好, 我是一位37多歲的電影/電視作曲家,現在我在想找一位安靜,有一個完整的時間表或是白天工作並且會說粵語的室友。男性或女性都好,沒有特別的偏好。 我在別的地方工作,在晚上我通常保持安靜。 我是一個很好相處,很隨和的室友,非常尊重公共空間和私人時間。我在這裡已經住了12年了, Brentwood是一個非常適合居住的地方。有時候我會邀請朋友過來,而且我不討厭一起在客廳看電影。我是一個美國人,但我可以用粵語對話。 空間已經附有家具,有2間臥室、2個浴室都擁有自己的鎖。給已經準備好入住的您!我的房間是最後一間,但你還是會有屬於自己的浴室。房租已經包含公用設施和網路費用。停車場是免費的。走在Brentwood可以去所有商店和餐館,並且還有720和920的紅色公車可以帶你到加州大學洛杉磯分校和聖莫尼卡。 請用英文回應這則廣告,因為我看不懂中文,但是我可以對話。 :)  期待與您見面!']

# %% [markdown]
# ### Visualization

# %%
import pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(nlp.lda_model, nlp.corpus, nlp.id2word)
vis
